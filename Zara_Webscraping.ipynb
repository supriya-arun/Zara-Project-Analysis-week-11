# %%
import requests
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup
import csv

# Endpoint and credentials
url = "https://realtime.oxylabs.io/v1/queries"
username = "zara_webscraping_yFPPa"
password = "Zara+11223344"  # Replace with your actual password

# Headers
headers = {
    "Content-Type": "application/json"
}

# List of URLs to scrape
URL_LIST = [
    "https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020",
    "https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=2",
    "https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=3",
    "https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=4",
    "https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=5"
    # Add more Zara category/product URLs here
]

# Function to fetch and parse product data from a single URL
def fetch_products_from_url(product_url):
    """
    Fetch product data from a Zara URL using Oxylabs proxy and parse the response.

    Args:
    - product_url (str): The URL to scrape.

    Returns:
    - list: A list of dictionaries containing product details.
    """
    # Payload
    data = {
        "source": "universal",
        "url": product_url
    }

    # Make the POST request
    response = requests.post(url, auth=HTTPBasicAuth(username, password), headers=headers, json=data)
    products = []

    if response.status_code == 200:
        try:
            # Parse the JSON response
            json_data = response.json()
            html_content = json_data['results'][0]['content']  # Adjust key as per your JSON structure

            # Parse the HTML content with BeautifulSoup
            soup = BeautifulSoup(html_content, 'html.parser')

            # Extract product information
            for product in soup.select('.product-grid-product'):  # Update the selector to match Zara's structure
                # Extract product details
                name = product.find('h2').get_text(strip=True) if product.find('h2') else "N/A"
                price = product.find('span', class_=r'money-amount__main').get_text(strip=True) if product.find('span', class_=r'money-amount__main') else "N/A"
                link = product.find('a', class_='product-link')['href'] if product.find('a', class_='product-link') else "#"

                # Construct full URL if necessary
                full_link = f"https://www.zara.com{link}" if not link.startswith("http") else link

                # Append product details to the list
                products.append({"name": name, "price": price, "url": full_link})

        except KeyError as e:
            print(f"Error parsing JSON response: Missing key {e}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
    else:
        print(f"Error: {response.status_code}, {response.text}")
    
    return products

# Function to fetch and save product data for multiple URLs
def fetch_and_save_all_products(url_list, output_file='zara_products.csv'):
    """
    Fetch product data from multiple Zara URLs and save them to a CSV file.

    Args:
    - url_list (list): List of Zara URLs to scrape.
    - output_file (str): The name of the output CSV file.
    """
    all_products = []

    for url in url_list:
        print(f"Scraping URL: {url}")
        products = fetch_products_from_url(url)
        all_products.extend(products)

    # Write the combined product data to a CSV file
    if all_products:
        with open(output_file, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=["name", "price", "url"])
            writer.writeheader()
            writer.writerows(all_products)
        print(f"Data successfully written to {output_file}")
    else:
        print("No product data fetched.")

# Run the scraper for multiple URLs
fetch_and_save_all_products(URL_LIST)
# Out:
# Scraping URL: https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020
# Scraping URL: https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=2
# Scraping URL: https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=3
# Scraping URL: https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=4
# Scraping URL: https://www.zara.com/de/en/woman-outerwear-coats-l1188.html?v1=2419020&page=5
# Data successfully written to zara_products.csv

# %%
import requests
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup
import csv

# Endpoint and credentials
url = "https://realtime.oxylabs.io/v1/queries"
username = "zara_webscraping_yFPPa"
password = "Zara+11223344"  # Replace with your actual password

# Headers
headers = {
    "Content-Type": "application/json"
}

# List of URLs to scrape
URL_LIST = [
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=2",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=3",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=4",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=5",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=6",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=7",
    "https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=8"
    
    # Add more Zara category/product URLs here
]

# Function to fetch and parse product data from a single URL
def fetch_products_from_url(product_url):
    """
    Fetch product data from a Zara URL using Oxylabs proxy and parse the response.

    Args:
    - product_url (str): The URL to scrape.

    Returns:
    - list: A list of dictionaries containing product details.
    """
    # Payload
    data = {
        "source": "universal",
        "url": product_url
    }

    # Make the POST request
    response = requests.post(url, auth=HTTPBasicAuth(username, password), headers=headers, json=data)
    products = []

    if response.status_code == 200:
        try:
            # Parse the JSON response
            json_data = response.json()
            html_content = json_data['results'][0]['content']  # Adjust key as per your JSON structure

            # Parse the HTML content with BeautifulSoup
            soup = BeautifulSoup(html_content, 'html.parser')

            # Extract product information
            for product in soup.select('.product-grid-product'):  # Update the selector to match Zara's structure
                # Extract product details
                name = product.find('h2').get_text(strip=True) if product.find('h2') else "N/A"
                price = product.find('span', class_=r'money-amount__main').get_text(strip=True) if product.find('span', class_=r'money-amount__main') else "N/A"
                link = product.find('a', class_='product-link')['href'] if product.find('a', class_='product-link') else "#"

                # Construct full URL if necessary
                full_link = f"https://www.zara.com{link}" if not link.startswith("http") else link

                # Append product details to the list
                products.append({"name": name, "price": price, "url": full_link})

        except KeyError as e:
            print(f"Error parsing JSON response: Missing key {e}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
    else:
        print(f"Error: {response.status_code}, {response.text}")
    
    return products

# Function to fetch and save product data for multiple URLs
def fetch_and_save_all_products(url_list, output_file='zara_products_bestsellers.csv'):
    """
    Fetch product data from multiple Zara URLs and save them to a CSV file.

    Args:
    - url_list (list): List of Zara URLs to scrape.
    - output_file (str): The name of the output CSV file.
    """
    all_products = []

    for url in url_list:
        print(f"Scraping URL: {url}")
        products = fetch_products_from_url(url)
        all_products.extend(products)

    # Write the combined product data to a CSV file
    if all_products:
        with open(output_file, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=["name", "price", "url"])
            writer.writeheader()
            writer.writerows(all_products)
        print(f"Data successfully written to {output_file}")
    else:
        print("No product data fetched.")

# Run the scraper for multiple URLs
fetch_and_save_all_products(URL_LIST)
# Out:
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=2
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=3
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=4
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=5
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=6
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=7
# Scraping URL: https://www.zara.com/de/en/woman-tshirts-basics-l1364.html?v1=2420405&page=8
# Data successfully written to zara_products_bestsellers.csv
